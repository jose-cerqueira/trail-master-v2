# %% [markdown]
# ### documentation
# https://docs.overturemaps.org/
#
# https://docs.fused.io/

# %%
import fused
import geopandas as gpd
import shapely

bbox = gpd.GeoDataFrame(
    geometry=[shapely.box(-73.9847, 40.7666, -73.9810, 40.7694)], 
    crs=4326
)
# Out:
# /Users/jose.cerqueira/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
fused.run('UDF_Overture_Maps_Example', bbox=bbox, overture_type='building')
# Out:
#                                      id  \
# 18262  08b2a100d65a6fff0200b45ce7e2b99b
# 18263  08b2a1008b259fff02007917db1c32d3
# 18306  08b2a100d6516fff0200ded2bf849c8a
# 18307  08b2a100d6516fff02006dc174022a7e
# 18308  08b2a1008b248fff0200315983940aa8
# 18309  08b2a1008b248fff0200f6545c6d6ef9
# 18310  08b2a1008b248fff0200c2f0e6f43833
# 18311  08b2a1008b248fff020095fcd33c31e5
# 18312  08b2a1008b24dfff0200ce215813f8fc
# 18313  08b2a100d6514fff0200f1cf659c1ad9
# 18315  08b2a100d6532fff020051de6f7cdf30
# 18316  08b2a1008b24dfff0200615f04f81560
# 18317  08b2a1008b24dfff020021abff34b147
# 18318  08b2a100d6536fff0200dc3affc7fb2f
# 18319  08b2a100d6530fff0200b74f1610e5f9
# 18320  08b2a100d6534fff02006dcc4de3c95d
# 18341  08b2a1008b25dfff0200554d3bb83624
# 18344  08b2a1008b25cfff0200897800043a0e
# 18366  08b2a1008b24efff0200feded5d505a7
# 18367  08b2a1008b243fff0200eaed6806a8da
# 18368  08b2a1008b24efff02009130c5e37020
# 18369  08b2a1008b24efff020000e1f3e9cbc9
# 18370  08b2a1008b24cfff02007453b6dd8184
# 18371  08b2a1008b24dfff0200e9639cc60a23
# 18372  08b2a1008b240fff02006f4cb849e47b
# 18373  08b2a1008b269fff0200bb85c2a5892b
# 18374  08b2a1008b269fff020010d13d1d803d
# 18375  08b2a1008b26efff020015ce48cb156e
# 18376  08b2a1008b262fff0200d611601922e0
# 18378  08b2a1008b265fff0200d3f44ff4d2d3
# 18379  08b2a1008b264fff02002e09fa29d91c
# 18892  08b2a100d6522fff020043f869921f59
# 18893  08b2a100d6522fff0200db54fb1a772d
# 18894  08b2a100d6523fff0200683aedce4637
# 18896  08b2a100d6524fff02009a1ce427fc0e
# 18897  08b2a100d6c99fff0200f99ebda87aff
# 18939  08b2a1008b26dfff0200fa071ecc5c1c
# 18940  08b2a100d6c90fff0200153a3c400962
# 18941  08b2a100d6c92fff0200f4e05473cc28
# 18942  08b2a100d6c90fff02004a599e39b6b7
# 18943  08b2a100d6c90fff0200b02435619ac1
#
#                                                 geometry  \
# 18262  POLYGON ((-73.98552 40.76736, -73.98557 40.767...
# 18263  POLYGON ((-73.98441 40.76703, -73.98431 40.767...
# 18306  POLYGON ((-73.98375 40.76693, -73.98381 40.766...
# 18307  POLYGON ((-73.98346 40.76623, -73.98327 40.766...
# 18308  POLYGON ((-73.98407 40.76749, -73.98402 40.767...
# 18309  POLYGON ((-73.98405 40.76738, -73.98404 40.767...
# 18310  POLYGON ((-73.98396 40.76735, -73.98386 40.767...
# 18311  POLYGON ((-73.9834 40.76741, -73.98348 40.7674...
# 18312  POLYGON ((-73.98332 40.76738, -73.98335 40.767...
# 18313  POLYGON ((-73.98323 40.76677, -73.98325 40.766...
# 18315  POLYGON ((-73.98294 40.76692, -73.98293 40.766...
# 18316  POLYGON ((-73.98308 40.76728, -73.98322 40.767...
# 18317  POLYGON ((-73.98322 40.76734, -73.98304 40.767...
# 18318  POLYGON ((-73.98322 40.76734, -73.98308 40.767...
# 18319  POLYGON ((-73.98204 40.76655, -73.982 40.76657...
# 18320  POLYGON ((-73.98211 40.7675, -73.98218 40.7674...
# 18341  POLYGON ((-73.98469 40.76796, -73.98468 40.767...
# 18344  POLYGON ((-73.98492 40.76774, -73.98491 40.767...
# 18366  POLYGON ((-73.98426 40.76778, -73.98432 40.767...
# 18367  POLYGON ((-73.98443 40.76794, -73.98432 40.768...
# 18368  POLYGON ((-73.98401 40.76773, -73.98388 40.767...
# 18369  POLYGON ((-73.98394 40.76752, -73.98391 40.767...
# 18370  POLYGON ((-73.98343 40.76752, -73.98331 40.767...
# 18371  POLYGON ((-73.98335 40.76739, -73.98318 40.767...
# 18372  POLYGON ((-73.98408 40.7684, -73.98403 40.7684...
# 18373  POLYGON ((-73.98243 40.76771, -73.98245 40.767...
# 18374  POLYGON ((-73.98326 40.7665, -73.98328 40.7665...
# 18375  POLYGON ((-73.98253 40.76848, -73.98249 40.768...
# 18376  POLYGON ((-73.98442 40.76938, -73.98424 40.769...
# 18378  POLYGON ((-73.98277 40.76955, -73.98279 40.769...
# 18379  POLYGON ((-73.98279 40.76952, -73.98277 40.769...
# 18892  POLYGON ((-73.98142 40.76642, -73.98133 40.766...
# 18893  POLYGON ((-73.98133 40.76654, -73.98121 40.766...
# 18894  POLYGON ((-73.98116 40.76678, -73.98119 40.766...
# 18896  POLYGON ((-73.98088 40.76715, -73.98103 40.766...
# 18897  POLYGON ((-73.98099 40.76739, -73.98101 40.767...
# 18939  POLYGON ((-73.98194 40.76812, -73.98197 40.768...
# 18940  POLYGON ((-73.98159 40.76872, -73.9816 40.7687...
# 18941  POLYGON ((-73.98191 40.76892, -73.98191 40.768...
# 18942  POLYGON ((-73.98159 40.76896, -73.98152 40.768...
# 18943  POLYGON ((-73.98146 40.76899, -73.98145 40.768...
#
#                                                     bbox  version  \
# 18262  {'xmax': -73.98454284667969, 'xmin': -73.98583...        0
# 18263  {'xmax': -73.98430633544922, 'xmin': -73.98557...        0
# 18306  {'xmax': -73.9837417602539, 'xmin': -73.984436...        0
# 18307  {'xmax': -73.983154296875, 'xmin': -73.9841079...        0
# 18308  {'xmax': -73.98401641845703, 'xmin': -73.98420...        0
# 18309  {'xmax': -73.98394012451172, 'xmin': -73.98413...        0
# 18310  {'xmax': -73.98385620117188, 'xmin': -73.98404...        0
# 18311  {'xmax': -73.98338317871094, 'xmin': -73.98396...        0
# 18312  {'xmax': -73.98330688476562, 'xmin': -73.98357...        0
# 18313  {'xmax': -73.98318481445312, 'xmin': -73.98325...        0
# 18315  {'xmax': -73.98275756835938, 'xmin': -73.98325...        0
# 18316  {'xmax': -73.98307800292969, 'xmin': -73.98349...        0
# 18317  {'xmax': -73.98303985595703, 'xmin': -73.98335...        0
# 18318  {'xmax': -73.98258972167969, 'xmin': -73.98321...        0
# 18319  {'xmax': -73.9819107055664, 'xmin': -73.982612...        0
# 18320  {'xmax': -73.98182678222656, 'xmin': -73.98219...        0
# 18341  {'xmax': -73.98467254638672, 'xmin': -73.98491...        0
# 18344  {'xmax': -73.98456573486328, 'xmin': -73.98541...        0
# 18366  {'xmax': -73.98406219482422, 'xmin': -73.98471...        0
# 18367  {'xmax': -73.98432159423828, 'xmin': -73.98481...        0
# 18368  {'xmax': -73.98387908935547, 'xmin': -73.98445...        0
# 18369  {'xmax': -73.98387145996094, 'xmin': -73.98410...        0
# 18370  {'xmax': -73.98330688476562, 'xmin': -73.98405...        0
# 18371  {'xmax': -73.9831771850586, 'xmin': -73.983489...        0
# 18372  {'xmax': -73.98392486572266, 'xmin': -73.98490...        0
# 18373  {'xmax': -73.9823989868164, 'xmin': -73.982460...        0
# 18374  {'xmax': -73.98097229003906, 'xmin': -73.98342...        0
# 18375  {'xmax': -73.98236083984375, 'xmin': -73.98399...        0
# 18376  {'xmax': -73.98347473144531, 'xmin': -73.98442...        0
# 18378  {'xmax': -73.98236846923828, 'xmin': -73.98291...        0
# 18379  {'xmax': -73.9827651977539, 'xmin': -73.983146...        0
# 18892  {'xmax': -73.9813232421875, 'xmin': -73.981636...        0
# 18893  {'xmax': -73.98115539550781, 'xmin': -73.98160...        0
# 18894  {'xmax': -73.98053741455078, 'xmin': -73.98143...        0
# 18896  {'xmax': -73.9804458618164, 'xmin': -73.981040...        0
# 18897  {'xmax': -73.98076629638672, 'xmin': -73.98152...        0
# 18939  {'xmax': -73.98181915283203, 'xmin': -73.98197...        0
# 18940  {'xmax': -73.98155212402344, 'xmin': -73.98161...        0
# 18941  {'xmax': -73.98186492919922, 'xmin': -73.98191...        0
# 18942  {'xmax': -73.98128509521484, 'xmin': -73.98179...        0
# 18943  {'xmax': -73.98126983642578, 'xmin': -73.98146...        0
#
#                                                  sources  level  \
# 18262  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18263  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18306  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18307  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18308  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18309  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18310  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18311  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18312  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18313  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18315  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18316  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18317  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18318  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18319  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18320  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18341  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18344  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18366  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18367  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18368  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18369  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18370  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18371  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18372  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18373  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18374  [{'confidence': None, 'dataset': 'OpenStreetMa...   -1.0
# 18375  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18376  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18378  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18379  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18892  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18893  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18894  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18896  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18897  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18939  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18940  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18941  [{'confidence': None, 'dataset': 'OpenStreetMa...    1.0
# 18942  [{'confidence': None, 'dataset': 'OpenStreetMa...    NaN
# 18943  [{'confidence': None, 'dataset': 'OpenStreetMa...    1.0
#
#               subtype          class  height  \
# 18262     residential     apartments    50.1
# 18263     residential     apartments    68.2
# 18306     residential     apartments   152.4
# 18307      commercial     commercial    30.0
# 18308            None           None    18.8
# 18309            None           None    19.4
# 18310            None           None    19.1
# 18311     residential     apartments    59.7
# 18312            None           None    19.2
# 18313            None           None     2.0
# 18315            None           None    25.0
# 18316     residential     apartments    47.8
# 18317      commercial          hotel    36.7
# 18318            None           None    28.0
# 18319      commercial     commercial   103.7
# 18320   entertainment           None    45.0
# 18341            None           None    18.7
# 18344            None           None    85.8
# 18366     residential     apartments    23.6
# 18367     residential     apartments   140.5
# 18368            None           None    23.6
# 18369            None           None     3.8
# 18370     residential     apartments    46.2
# 18371            None           None    17.1
# 18372     residential     apartments    40.4
# 18373         service        service     3.5
# 18374  transportation  train_station     NaN
# 18375            None           None    45.0
# 18376     residential     apartments    40.4
# 18378     residential     apartments     NaN
# 18379       education         school    40.5
# 18892            None           None    56.6
# 18893            None           None    88.1
# 18894     residential     apartments   472.0
# 18896            None           None   290.0
# 18897     residential     apartments    89.9
# 18939            None           None    25.0
# 18940            None           None     NaN
# 18941            None           None     NaN
# 18942            None           None   171.0
# 18943     outbuilding           roof     6.8
#
#                                                    names  ...  min_height  \
# 18262                                               None  ...         NaN
# 18263                                               None  ...         NaN
# 18306  {'common': None, 'primary': 'The Sheffield 57'...  ...         NaN
# 18307  {'common': [['no', 'Hearst-bygningen'], ['ru',...  ...         NaN
# 18308                                               None  ...         NaN
# 18309                                               None  ...         NaN
# 18310                                               None  ...         NaN
# 18311                                               None  ...         NaN
# 18312                                               None  ...         NaN
# 18313                                               None  ...         NaN
# 18315  {'common': None, 'primary': 'Central Park Plac...  ...         NaN
# 18316                                               None  ...         NaN
# 18317  {'common': None, 'primary': '6 Columbus', 'rul...  ...         NaN
# 18318                                               None  ...         NaN
# 18319                                               None  ...         NaN
# 18320  {'common': None, 'primary': 'Museum of Arts an...  ...         NaN
# 18341                                               None  ...         NaN
# 18344  {'common': None, 'primary': 'Hudson Hotel', 'r...  ...         NaN
# 18366  {'common': None, 'primary': 'The Westmore', 'r...  ...         NaN
# 18367  {'common': None, 'primary': 'The Colonnade', '...  ...         NaN
# 18368                                               None  ...         NaN
# 18369                                               None  ...         NaN
# 18370                                               None  ...         NaN
# 18371                                               None  ...         NaN
# 18372  {'common': None, 'primary': 'Coliseum Park Apa...  ...         NaN
# 18373                                               None  ...         NaN
# 18374  {'common': None, 'primary': '59th Street–Colum...  ...         NaN
# 18375  {'common': [['ru', 'Тайм-Уорнер-Центр'], ['uk'...  ...         NaN
# 18376  {'common': None, 'primary': 'Coliseum Park Apa...  ...         NaN
# 18378  {'common': None, 'primary': 'Anagram Columbus ...  ...         NaN
# 18379  {'common': None, 'primary': 'The Shefa School'...  ...         NaN
# 18892                                               None  ...         NaN
# 18893                                               None  ...         NaN
# 18894  {'common': [['en', 'Central Park Tower']], 'pr...  ...         NaN
# 18896                                               None  ...         NaN
# 18897                                               None  ...         NaN
# 18939  {'common': [['kn', 'ಕ್ರಿಸ್ಟೊಫರ್ ಕೊಲಂಬಸ್'], ['r...  ...         NaN
# 18940                                               None  ...         NaN
# 18941                                               None  ...         NaN
# 18942  {'common': None, 'primary': 'Trump Internation...  ...         NaN
# 18943                                               None  ...         NaN
#
#        min_floor  facade_color  facade_material  roof_material  roof_shape  \
# 18262        NaN          None             None           None        None
# 18263        NaN          None             None           None        None
# 18306        NaN          None            brick           None        None
# 18307        NaN       #9D937A             None       concrete        flat
# 18308        NaN          None             None           None        None
# 18309        NaN          None             None           None        None
# 18310        NaN          None             None           None        None
# 18311        NaN          None             None           None        None
# 18312        NaN          None             None           None        None
# 18313        NaN          None             None           None        None
# 18315        NaN          None             None       concrete        flat
# 18316        NaN          None             None           None        None
# 18317        NaN          None             None           None        None
# 18318        NaN          None             None           None        None
# 18319        NaN          None             None           None        None
# 18320        NaN          None         concrete       concrete        flat
# 18341        NaN          None             None           None        None
# 18344        NaN          None             None           None        None
# 18366        NaN          None             None           None        None
# 18367        NaN          None             None           None        None
# 18368        NaN          None             None           None        None
# 18369        NaN          None             None           None        None
# 18370        NaN          None             None           None        None
# 18371        NaN          None             None           None        None
# 18372        NaN       #8C816F            brick       concrete        None
# 18373        NaN          None             None           None        None
# 18374        NaN          None             None           None        None
# 18375        NaN       #293D55            glass       concrete        flat
# 18376        NaN       #8C816F            brick       concrete        None
# 18378        NaN          None             None           None        None
# 18379        NaN          None             None           None        flat
# 18892        NaN          None             None           None        None
# 18893        NaN          None             None           None        None
# 18894        NaN          None             None           None        None
# 18896        NaN          None             None           None        None
# 18897        NaN          None             None           None        None
# 18939        NaN          None         concrete       concrete        flat
# 18940        NaN          None             None           None        None
# 18941        NaN          None             None           None        None
# 18942        NaN       #6C541E            glass       concrete        flat
# 18943        NaN          None             None           None        None
#
#       roof_direction roof_orientation roof_color roof_height
# 18262            NaN             None       None         NaN
# 18263            NaN             None       None         NaN
# 18306            NaN             None       None         NaN
# 18307            NaN             None       None         NaN
# 18308            NaN             None       None         NaN
# 18309            NaN             None       None         NaN
# 18310            NaN             None       None         NaN
# 18311            NaN             None       None         NaN
# 18312            NaN             None       None         NaN
# 18313            NaN             None       None         NaN
# 18315            NaN             None       None         NaN
# 18316            NaN             None       None         NaN
# 18317            NaN             None       None         NaN
# 18318            NaN             None       None         NaN
# 18319            NaN             None       None         NaN
# 18320            NaN             None       None         NaN
# 18341            NaN             None       None         NaN
# 18344            NaN             None       None         NaN
# 18366            NaN             None       None         NaN
# 18367            NaN             None       None         NaN
# 18368            NaN             None       None         NaN
# 18369            NaN             None       None         NaN
# 18370            NaN             None       None         NaN
# 18371            NaN             None       None         NaN
# 18372            NaN             None       None         NaN
# 18373            NaN             None       None         NaN
# 18374            NaN             None       None         NaN
# 18375            NaN             None       None         NaN
# 18376            NaN             None       None         NaN
# 18378            NaN             None       None         NaN
# 18379            NaN             None       None         NaN
# 18892            NaN             None       None         NaN
# 18893            NaN             None       None         NaN
# 18894            NaN             None       None         NaN
# 18896            NaN             None       None         NaN
# 18897            NaN             None       None         NaN
# 18939            NaN             None       None         NaN
# 18940            NaN             None       None         NaN
# 18941            NaN             None       None         NaN
# 18942            NaN             None       None         NaN
# 18943            NaN             None       None         NaN
#
# [41 rows x 24 columns]
